# %% [markdown]
# # Def /////////////////////////////////////////////////

# %%
import numpy as np
import cv2
# %matplotlib inline
import matplotlib.pyplot as plt
from itertools import chain, zip_longest
import random
import time
import math
import wave
import struct

# %% [markdown]
# # image

# %%
def divide1d(lst, group_num):
    lstlen = len(lst)
    quotient = int(lstlen/group_num)
    rst = lstlen%group_num
    if rst == 0 :
        dividedlist = list(zip(*[iter(lst)]*quotient))
    elif rst > 0 :
        dividedlist = list(zip(*[iter(lst)]*(quotient+1)))
        dividedlist = dividedlist[0:rst]
        rstlst = range(dividedlist[-1][-1]+1, lstlen)
        dividedlist.extend( list(zip(*[iter(rstlst)]*(quotient))) )
    
    for i in range(len(dividedlist)):
        dividedlist[i] = list(dividedlist[i])

    return(dividedlist)


def divideimage(img, divw, divh):
    height, width, channels = img.shape
    heights =  divide1d(range(height), divh)
    widths =  divide1d(range(width), divw)
    
    imgF = np.float_(img)

    dividedimgs = []
    for ih in range(0,divh,1):
        temp = []
        for iw in range(0,divw,1):
            temp.append( imgF[heights[ih][0]:heights[ih][-1], widths[iw][0]:widths[iw][-1]] )
        dividedimgs.append( temp )
    
    return(heights, widths, dividedimgs)


def mean_image(img):
    flattened_img = np.array(list(chain.from_iterable(img)))
    mean_img =  sum(flattened_img)/len(flattened_img)
    return(mean_img)


def hsv2rgb(h, s, v):
    h = float(h)
    s = float(s)
    v = float(v)
    h60 = h / 60.0
    h60f = math.floor(h60)
    hi = int(h60f) % 6
    f = h60 - h60f
    p = v * (1 - s)
    q = v * (1 - f * s)
    t = v * (1 - (1 - f) * s)
    r, g, b = 0, 0, 0
    if hi == 0: r, g, b = v, t, p
    elif hi == 1: r, g, b = q, v, p
    elif hi == 2: r, g, b = p, v, t
    elif hi == 3: r, g, b = p, q, v
    elif hi == 4: r, g, b = t, p, v
    elif hi == 5: r, g, b = v, p, q
    r, g, b = int(r * 255), int(g * 255), int(b * 255)
    return r, g, b
    
def rgb2hsv(r, g, b):
    r, g, b = r/255.0, g/255.0, b/255.0
    mx = max(r, g, b)
    mn = min(r, g, b)
    df = mx-mn
    if mx == mn:
        h = 0
    elif mx == r:
        h = (60 * ((g-b)/df) + 360) % 360
    elif mx == g:
        h = (60 * ((b-r)/df) + 120) % 360
    elif mx == b:
        h = (60 * ((r-g)/df) + 240) % 360
    if mx == 0:
        s = 0
    else:
        s = df/mx
    v = mx
    return h, s, v

# R, G, B values are [0, 255]. H value is [0, 360]. S, V values are [0, 1].

# %% [markdown]
# # music

# %%
def makewave(amp,freq,sec,sr):
    outwave = []
    for i in range( int(sec*sr) ) :
        w = amp*np.sin(2*np.pi*freq*i/sr)
        outwave.append(w)
    return(outwave)


def wavwrite(inputlist,filename):
    maxamp = 32767.0
    int16wave = [int(x * maxamp) for x in inputlist]
    binwave = struct.pack("h"*len(int16wave),*int16wave)

    nchannnles = 1 # 1=monoral , 2=stereo
    sampwitdth = 2 # 1=8bit,2=16bit,3=,...
    framerate = 44100 # sampling rate ex.44100Hz
    nframes = len(inputlist) # framerate * sec
    
    of = wave.open(filename,"w")
    of.setparams((nchannnles,sampwitdth,framerate,nframes,"NONE","not compressed"))
    of.writeframes(binwave)
    of.close
    
    
# amp
def ampFn(amp_type,t,t0,T,amp,aparam):
    # t0: initial time
    # T: length of time for sound
    # t1: time of peak
    # a1: trancation exponent(a1=1: NoEffect, 1<<a1: too tracate)
    # a2: trancation exponent(0<a2, 0<a2<<1: too tracate, 1<<a2: NoEffect
    # a1=-1&a2=1: convex trancation shape
    t1 = aparam[0]
    a1 = aparam[1]
    a2 = aparam[2]
    if amp_type == 1:
        if t <= t0:
            ampVal = 0
        else:
            if t <= t0 + t1:
                ampVal = amp*(t-t0)/t1
            else:
                ampVal = amp*(-(t-T)/T)*((t1+a2)/(t-t0+a2))**a1
    elif amp_type == 2:
        if t <= t0:
            ampVal = 0
        else:
            ampVal = amp*(1-(t-t0)/T)**2
    elif amp_type == 3:
        if t <= t0:
            ampVal = 0
        else:
            ampVal = amp*(1-((t-t0)/T)**(1/10))


    return(ampVal)


def waveFn(wave_type,t,t1,param,freq):
    if   wave_type == 1:
        #Sin Wave
        wave = np.sin(2*np.pi * freq*t)
    elif wave_type == 2:
        #Sawtooth Wave
        wave = 2*((t-t1)*freq - np.floor((t-t1)*freq + 0.5))
    elif wave_type == 3:
        #Triangle Wave
        wave = 2*abs(2*((t-t1+1/(4*freq))*freq - np.floor((t-t1+1/(4*freq))*freq + 0.5)))-1
    elif wave_type == 4:
        #Square Wave
        wave = np.sign(np.sin(2*np.pi * freq*t))
    elif wave_type == 5:
        #Pulse Wave 1
        wave = np.sign(- (t-t1)*freq + np.floor((t-t1)*freq) + param[0])
    return(wave)



#def makeampFnwave(amp, freq, T, dT, sr, aparam):
def makeampFnwave(amp, freq, T, sr, aparam):
    outwave = []
#    T = np.around(T/dT)*dT
    dt = 1/sr
    t0 = 0
    for t in np.arange( 0., T+dt, dt ) :
#        w = ampFn(1, t, t0, T, amp, aparam)*np.sin(2*np.pi*freq*t)
#        w = ampFn(2, t, t0, T, amp, aparam)*np.sin(2*np.pi*freq*t)
#        w = ampFn(1, t, t0, T, amp, aparam) * ( waveFn(1, t, 0, 1, freq) + waveFn(1, t, 0, 1, 2*freq)/4 + waveFn(1, t, 0, 1, 3*freq)/6 + waveFn(1, t, 0, 1, 4*freq)/8 )
        w = ampFn(2, t, t0, T, amp, aparam) * ( waveFn(1, t, 0, 1, freq) + waveFn(1, t, 0, 1, 2*freq)/4 + waveFn(1, t, 0, 1, 3*freq)/6 + waveFn(1, t, 0, 1, 4*freq)/8 )
#        w = ampFn(3, t, t0, T, amp, aparam) * ( waveFn(1, t, 0, 1, freq) + waveFn(1, t, 0, 1, 2*freq)/4 + waveFn(1, t, 0, 1, 3*freq)/6 + waveFn(1, t, 0, 1, 4*freq)/8 )
        outwave.append(w)
    return(outwave)


def color2key(initial_octave, plus_octave, initial_key, color):
    keymin = 12*initial_octave + initial_key
    keymax = 12*(initial_octave + plus_octave) + initial_key + 1
    dkey = keymax - keymin

    freq_temp = keymin + dkey * color / 255
#    freq_temp = keymin + int(dkey * color / 255)
    freq_temp2 = math.pow(2.0, freq_temp)
    freq = 27.5 * ((freq_temp2) ** (1.0/12.0))
    
    return(freq)

def hue2key(initial_octave, plus_octave, initial_key, colors):
    color = colors[0]
    colormin = colors[1]
    colormax = colors[2]
    dcolor = colormax-colormin
    keymin = 12*initial_octave + initial_key
    keymax = 12*(initial_octave + plus_octave) + initial_key + 1
    dkey = keymax - keymin

    # C0=1, C4=39
#    whites = [39, 41, 43, 44, 46, 48, 50, 52]
#    blacks = [40, 42, 45, 47, 49, 51]
    whitebase=[1,3,5,6,8,10,12]
    blackbase=[2,4,7,9,11]
    whites = []
    blacks = []
    for i in range(initial_octave, initial_octave+plus_octave+1):
        whites.append( np.array(whitebase)+12*i )
        blacks.append( np.array(blackbase)+12*i )
    whites = np.concatenate(whites).tolist()
    blacks = np.concatenate(blacks).tolist()
    
#    freq_temp = keymin + dkey * color / 360
#    freq_temp = keymin + dkey * (color-colormin)/(colormax-colormin)
    colortld = (color-colormin)/(colormax-colormin)
    freq_temp0 = int( 7*plus_octave*colortld**(4) )
    freq_temp = whites[freq_temp0]
    freq_temp2 = math.pow(2.0, freq_temp)
    freq = 27.5 * ((freq_temp2) ** (1.0/12.0))
    
    return(freq)

# %%
def merge1d(lst0, lst1):
    len0 = len(lst0)
    len1 = len(lst1)
    aft0 = max([len0, len1])-len0
    aft1 = max([len0, len1])-len1
    mergedlst = np.lib.pad(lst0,(0, aft0),"constant",constant_values = 0) + np.lib.pad(lst1,(0, aft1),"constant",constant_values = 0)
    return(mergedlst)

# %% [markdown]
# # main ///////////////////////////////////////////////////////////

# %%
start_whole_time = time.time()

# %% [markdown]
# # image

# %%
#img = cv2.imread("../../_fig/_others/miporin.jpg")
img = cv2.imread("../../_fig/monet/woman_withparasol.jpg")
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
height, width, channels = img.shape
plt.imshow(img)

# %% [markdown]
# ## melody part  --------------------------------------

# %%
divw = 50
divh = 50
heights, widths, dividedimgs = divideimage(img, divw, divh)
#print(dividedimgs.shape)
#dividedimgs

# %%
decolorRGBs = []
decolorHSVs = []
for iw in range(divw):
    tempRGB = []
    tempHSV = []
    for ih in range(divh):
#        meanRGB = mean_image(dividedimgs[ih,iw])
#        print(dividedimgs[ih][iw])
        meanRGB = mean_image(dividedimgs[ih][iw])
#        print(meanRGB)
        tempRGB.append( meanRGB )
        tempHSV.append( rgb2hsv(meanRGB[0],meanRGB[1],meanRGB[2]) )
    decolorRGBs.append(tempRGB)
    decolorHSVs.append(tempHSV)
decolorRGBs = np.array(decolorRGBs)
decolorHSVs = np.array(decolorHSVs)

print(decolorRGBs.shape)
# Out:
# (50, 50, 3)

# %%
codesRGBF = []
codesHSVF = []
codes = []
icode = 0
iw = int(divw/2)
ih = int(divh/2)
codesRGBF.append( decolorRGBs[iw,ih] )
codesRGBF = np.array(codesRGBF)
#print(codesRGBF)

codesHSVF.append( decolorHSVs[iw,ih] )
codesHSVF = np.array(codesHSVF)
#print(codesHSVF)

#icode0 = 0
icodemax = 300
diw = 1
dih = 1
iwhssetall = []
icheckth = 1
for iih in range(divh):
    for iiw in range(divw):
        iwhssetall.append(str(iiw)+","+str(iih))
         
iwhsset = set([])
iwhs = []
ilogs = []
iwhs.append([iw,ih])
ilogs.append([0,9,iw,ih])
print("[icode, inextposition, iw,ih]", ilogs[0])
inextpositions = []
icheck = 0
#for ii in range(icodemax):
while (len(iwhsset) != len(iwhssetall)) and (icode < icodemax) :
    icode = icode + 1
                
    nextsRGBF = []
    nextsHSVF = []
    inextpositionBoundaries =[]
    iBoundaries = [0,0,0,0]
    if(iw+diw <= divw-1):
        nextsRGBF.append( decolorRGBs[iw+diw,ih] )
        nextsHSVF.append( decolorHSVs[iw+diw,ih] )
    else:
        if(iw < divw-1):
            nextsRGBF.append( decolorRGBs[divw-1,ih] )
            nextsHSVF.append( decolorHSVs[divw-1,ih] )
            iBoundaries[0] = 1
        else:
            nextsRGBF.append( np.array([random.random(),random.random(),random.random()]) )
            nextsHSVF.append( [random.random(),random.random(),random.random()] )
            inextpositionBoundaries.append(0)

    if(iw-diw >= 0):
        nextsRGBF.append( decolorRGBs[iw-diw,ih] )
        nextsHSVF.append( decolorHSVs[iw-diw,ih] )
    else:
        if(iw > 0):
            nextsRGBF.append( decolorRGBs[0,ih] )
            nextsHSVF.append( decolorHSVs[0,ih] )
            iBoundaries[1] = 1
        else:
            nextsRGBF.append( np.array([random.random(),random.random(),random.random()]) )
            inextpositionBoundaries.append(1)
            nextsHSVF.append( [random.random(),random.random(),random.random()] )

    if(ih+dih <= divh-1):
        nextsRGBF.append( decolorRGBs[iw,ih+dih] )
        nextsHSVF.append( decolorHSVs[iw,ih+dih] )
    else:
        if(ih < divh-1):
            nextsRGBF.append( decolorRGBs[iw,divh-1] )
            nextsHSVF.append( decolorHSVs[iw,divh-1] )
            iBoundaries[2] = 1
        else:
            nextsRGBF.append( np.array([random.random(),random.random(),random.random()]) )
            inextpositionBoundaries.append(2)
            nextsHSVF.append( [random.random(),random.random(),random.random()] )

    if(ih-dih >= 0):
        nextsRGBF.append( decolorRGBs[iw,ih-dih] )
        nextsHSVF.append( decolorHSVs[iw,ih-dih] )
    else:
        if(ih > 0):
            nextsRGBF.append( decolorRGBs[iw,0] )
            nextsHSVF.append( decolorHSVs[iw,0] )
            iBoundaries[3] = 1
        else:
            nextsRGBF.append( np.array([random.random(),random.random(),random.random()]) )
            inextpositionBoundaries.append(3)
            nextsHSVF.append( [random.random(),random.random(),random.random()] )
            #print("hello3c")

    nextsHSVF = np.array(nextsHSVF)
    nextsRGBF = np.array(nextsRGBF)

    nextsHF = nextsHSVF[:,0]
    dHues = abs( nextsHF - codesHSVF[icode-1,0] )
    
    dHuesSort = np.sort(dHues)
    dHuesSort

    dHuesindex = []
    for i in range(len(dHues)):
        dHuesindex.append( dHues.tolist().index(dHuesSort[i]) )

    dHuesindexbad = set([])
    if( icode > 1 ):
        if( inextpositionold != 9 ):
            dHuesindexbad.add( dHuesindex.index(inextpositionold) )
    if(len(inextpositionBoundaries) > 0):
        for i in range(len(inextpositionBoundaries)):
            if( icode > 1 ):
                if( inextpositionold != 9 ):
                    if( dHuesindex.index(inextpositionold) != dHuesindex.index(inextpositionBoundaries[i]) ):
                        dHuesindexbad.add( dHuesindex.index(inextpositionBoundaries[i]) )
    dHuesindexbad = list(dHuesindexbad)

    dHuesindexbad = sorted(dHuesindexbad, reverse=True)

    if( len(dHuesindexbad) > 0 ):
        for i in range( len(dHuesindexbad) ):
            dHuesindex.pop( dHuesindexbad[i] )

    inextposition = dHuesindex[0]   #close color
#    inextposition = dHuesindex[ len(dHuesindex)-1 ]   #different color
#    inextposition = dHuesindex[ random.randint(0,len(dHuesindex)-1) ]
    inextpositions.append(inextposition)

    codesRGBF = np.concatenate(np.array([codesRGBF, [nextsRGBF[inextposition]] ]))
    codesHSVF = np.concatenate(np.array([codesHSVF, [nextsHSVF[inextposition]] ]))

    if(inextposition == 0):
        if(iBoundaries[inextposition] == 1):
            iw = divw - 1
        else:
            iw = iw + diw
        inextpositionold = 1
            
    if(inextposition == 1):
        if(iBoundaries[inextposition] == 1):
            iw = 0
        else:
            iw = iw - diw
        inextpositionold = 0
    if(inextposition == 2):
        if(iBoundaries[inextposition] == 1):
            ih = divh - 1
        else:
            ih = ih + dih
        inextpositionold = 3
    if(inextposition == 3):
        if(iBoundaries[inextposition] == 1):
            ih = 0
        else:
            ih = ih - dih
        inextpositionold = 2
    if(np.mod(icode,1)==0):
#    if(icode>10):
        print("[icode, inextposition, iw,ih]", [icode, inextposition, iw,ih])
    iwhsset.add(str(iw)+","+str(ih))
    
    diw = 1
    dih = 1
    ilogscount = ilogs.count([inextposition,iw,ih])
    if( ilogscount > 0 ):
        dih = ilogscount + 1
        diw = ilogscount + 1
        deltaiwsort = sorted([abs(divw-iw)-1,iw])
        deltaihsort = sorted([abs(divh-ih)-1,ih])
        if( deltaiwsort[1] < diw ):
            diw = deltaiwsort[0]
            if( deltaiwsort[0] == 0 ):
                diw = deltaiwsort[0] + 1
        if( deltaihsort[1] < dih ):
            dih = deltaihsort[0]
            if( deltaihsort[0] == 0 ):
                dih = deltaihsort[0] + 1
        print("diw", diw, "   dih", dih)
        
        if( icheck < icheckth ):
            if( deltaiwsort[0] == 0 ):
                if( deltaihsort[0] == 0 ):
                    icheck += 1
        if( icheck == icheckth ):
            if( deltaiwsort[0] == 0 ):
                if( deltaihsort[0] == 0 ):
                    if(set(iwhssetall) != iwhsset):
                        iwhssetrem = set(iwhssetall).difference(iwhsset)
                        iwhsrem=",".join(iwhssetrem)
                        iwhsrem=iwhsrem.split(",")
                        iw = int(iwhsrem[0])
                        ih = int(iwhsrem[1])

                    if(set(iwhssetall) == iwhsset):
                        iw = np.array(iwhs)[0,0]
                        ih = np.array(iwhs)[0,1]
            
                    inextposition = 9
                    print("[icode, inextposition, iw,ih]", [icode, inextposition, iw,ih])
                    iwhsset.add(str(iw)+","+str(ih))
                    
                    icheck = 0

                    codesRGBF[icode] = decolorRGBs[iw,ih]
                    codesHSVF[icode] = decolorHSVs[iw,ih]
                    inextposition = 9

    iwhs.append([iw,ih])
    ilogs.append([inextposition,iw,ih])
# Out:
# [icode, inextposition, iw,ih] [0, 9, 25, 25]
# [icode, inextposition, iw,ih] [1, 3, 25, 24]
# [icode, inextposition, iw,ih] [2, 1, 24, 24]
# [icode, inextposition, iw,ih] [3, 2, 24, 25]
# [icode, inextposition, iw,ih] [4, 0, 25, 25]
# [icode, inextposition, iw,ih] [5, 3, 25, 24]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [6, 0, 27, 24]
# [icode, inextposition, iw,ih] [7, 0, 28, 24]
# [icode, inextposition, iw,ih] [8, 0, 29, 24]
# [icode, inextposition, iw,ih] [9, 2, 29, 25]
# [icode, inextposition, iw,ih] [10, 0, 30, 25]
# [icode, inextposition, iw,ih] [11, 0, 31, 25]
# [icode, inextposition, iw,ih] [12, 0, 32, 25]
# [icode, inextposition, iw,ih] [13, 0, 33, 25]
# [icode, inextposition, iw,ih] [14, 0, 34, 25]
# [icode, inextposition, iw,ih] [15, 2, 34, 26]
# [icode, inextposition, iw,ih] [16, 0, 35, 26]
# [icode, inextposition, iw,ih] [17, 2, 35, 27]
# [icode, inextposition, iw,ih] [18, 2, 35, 28]
# [icode, inextposition, iw,ih] [19, 1, 34, 28]
# [icode, inextposition, iw,ih] [20, 2, 34, 29]
# [icode, inextposition, iw,ih] [21, 0, 35, 29]
# [icode, inextposition, iw,ih] [22, 3, 35, 28]
# [icode, inextposition, iw,ih] [23, 1, 34, 28]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [24, 2, 34, 30]
# [icode, inextposition, iw,ih] [25, 0, 35, 30]
# [icode, inextposition, iw,ih] [26, 3, 35, 29]
# [icode, inextposition, iw,ih] [27, 1, 34, 29]
# [icode, inextposition, iw,ih] [28, 3, 34, 28]
# [icode, inextposition, iw,ih] [29, 0, 35, 28]
# [icode, inextposition, iw,ih] [30, 3, 35, 27]
# [icode, inextposition, iw,ih] [31, 3, 35, 26]
# [icode, inextposition, iw,ih] [32, 1, 34, 26]
# [icode, inextposition, iw,ih] [33, 3, 34, 25]
# [icode, inextposition, iw,ih] [34, 1, 33, 25]
# [icode, inextposition, iw,ih] [35, 1, 32, 25]
# [icode, inextposition, iw,ih] [36, 1, 31, 25]
# [icode, inextposition, iw,ih] [37, 1, 30, 25]
# [icode, inextposition, iw,ih] [38, 1, 29, 25]
# [icode, inextposition, iw,ih] [39, 3, 29, 24]
# [icode, inextposition, iw,ih] [40, 1, 28, 24]
# [icode, inextposition, iw,ih] [41, 1, 27, 24]
# [icode, inextposition, iw,ih] [42, 1, 26, 24]
# [icode, inextposition, iw,ih] [43, 2, 26, 25]
# [icode, inextposition, iw,ih] [44, 1, 25, 25]
# [icode, inextposition, iw,ih] [45, 3, 25, 24]
# diw 3    dih 3
# [icode, inextposition, iw,ih] [46, 1, 22, 24]
# [icode, inextposition, iw,ih] [47, 3, 22, 23]
# [icode, inextposition, iw,ih] [48, 3, 22, 22]
# [icode, inextposition, iw,ih] [49, 1, 21, 22]
# [icode, inextposition, iw,ih] [50, 1, 20, 22]
# [icode, inextposition, iw,ih] [51, 1, 19, 22]
# [icode, inextposition, iw,ih] [52, 3, 19, 21]
# [icode, inextposition, iw,ih] [53, 1, 18, 21]
# [icode, inextposition, iw,ih] [54, 3, 18, 20]
# [icode, inextposition, iw,ih] [55, 0, 19, 20]
# [icode, inextposition, iw,ih] [56, 0, 20, 20]
# [icode, inextposition, iw,ih] [57, 0, 21, 20]
# [icode, inextposition, iw,ih] [58, 0, 22, 20]
# [icode, inextposition, iw,ih] [59, 0, 23, 20]
# [icode, inextposition, iw,ih] [60, 0, 24, 20]
# [icode, inextposition, iw,ih] [61, 2, 24, 21]
# [icode, inextposition, iw,ih] [62, 1, 23, 21]
# [icode, inextposition, iw,ih] [63, 1, 22, 21]
# [icode, inextposition, iw,ih] [64, 1, 21, 21]
# [icode, inextposition, iw,ih] [65, 1, 20, 21]
# [icode, inextposition, iw,ih] [66, 3, 20, 20]
# [icode, inextposition, iw,ih] [67, 0, 21, 20]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [68, 0, 23, 20]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [69, 2, 23, 22]
# [icode, inextposition, iw,ih] [70, 1, 22, 22]
# [icode, inextposition, iw,ih] [71, 2, 22, 23]
# [icode, inextposition, iw,ih] [72, 1, 21, 23]
# [icode, inextposition, iw,ih] [73, 2, 21, 24]
# [icode, inextposition, iw,ih] [74, 0, 22, 24]
# [icode, inextposition, iw,ih] [75, 3, 22, 23]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [76, 3, 22, 21]
# [icode, inextposition, iw,ih] [77, 0, 23, 21]
# [icode, inextposition, iw,ih] [78, 2, 23, 22]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [79, 1, 21, 22]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [80, 2, 21, 24]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [81, 1, 19, 24]
# [icode, inextposition, iw,ih] [82, 2, 19, 25]
# [icode, inextposition, iw,ih] [83, 1, 18, 25]
# [icode, inextposition, iw,ih] [84, 1, 17, 25]
# [icode, inextposition, iw,ih] [85, 3, 17, 24]
# [icode, inextposition, iw,ih] [86, 0, 18, 24]
# [icode, inextposition, iw,ih] [87, 2, 18, 25]
# [icode, inextposition, iw,ih] [88, 1, 17, 25]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [89, 1, 15, 25]
# [icode, inextposition, iw,ih] [90, 1, 14, 25]
# [icode, inextposition, iw,ih] [91, 1, 13, 25]
# [icode, inextposition, iw,ih] [92, 3, 13, 24]
# [icode, inextposition, iw,ih] [93, 1, 12, 24]
# [icode, inextposition, iw,ih] [94, 1, 11, 24]
# [icode, inextposition, iw,ih] [95, 2, 11, 25]
# [icode, inextposition, iw,ih] [96, 0, 12, 25]
# [icode, inextposition, iw,ih] [97, 0, 13, 25]
# [icode, inextposition, iw,ih] [98, 3, 13, 24]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [99, 1, 11, 24]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [100, 2, 11, 26]
# [icode, inextposition, iw,ih] [101, 2, 11, 27]
# [icode, inextposition, iw,ih] [102, 2, 11, 28]
# [icode, inextposition, iw,ih] [103, 1, 10, 28]
# [icode, inextposition, iw,ih] [104, 2, 10, 29]
# [icode, inextposition, iw,ih] [105, 0, 11, 29]
# [icode, inextposition, iw,ih] [106, 0, 12, 29]
# [icode, inextposition, iw,ih] [107, 2, 12, 30]
# [icode, inextposition, iw,ih] [108, 0, 13, 30]
# [icode, inextposition, iw,ih] [109, 0, 14, 30]
# [icode, inextposition, iw,ih] [110, 3, 14, 29]
# [icode, inextposition, iw,ih] [111, 0, 15, 29]
# [icode, inextposition, iw,ih] [112, 3, 15, 28]
# [icode, inextposition, iw,ih] [113, 0, 16, 28]
# [icode, inextposition, iw,ih] [114, 0, 17, 28]
# [icode, inextposition, iw,ih] [115, 0, 18, 28]
# [icode, inextposition, iw,ih] [116, 3, 18, 27]
# [icode, inextposition, iw,ih] [117, 0, 19, 27]
# [icode, inextposition, iw,ih] [118, 0, 20, 27]
# [icode, inextposition, iw,ih] [119, 3, 20, 26]
# [icode, inextposition, iw,ih] [120, 1, 19, 26]
# [icode, inextposition, iw,ih] [121, 1, 18, 26]
# [icode, inextposition, iw,ih] [122, 1, 17, 26]
# [icode, inextposition, iw,ih] [123, 1, 16, 26]
# [icode, inextposition, iw,ih] [124, 1, 15, 26]
# [icode, inextposition, iw,ih] [125, 3, 15, 25]
# [icode, inextposition, iw,ih] [126, 1, 14, 25]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [127, 1, 12, 25]
# [icode, inextposition, iw,ih] [128, 2, 12, 26]
# [icode, inextposition, iw,ih] [129, 1, 11, 26]
# [icode, inextposition, iw,ih] [130, 2, 11, 27]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [131, 1, 9, 27]
# [icode, inextposition, iw,ih] [132, 1, 8, 27]
# [icode, inextposition, iw,ih] [133, 2, 8, 28]
# [icode, inextposition, iw,ih] [134, 1, 7, 28]
# [icode, inextposition, iw,ih] [135, 1, 6, 28]
# [icode, inextposition, iw,ih] [136, 1, 5, 28]
# [icode, inextposition, iw,ih] [137, 2, 5, 29]
# [icode, inextposition, iw,ih] [138, 1, 4, 29]
# [icode, inextposition, iw,ih] [139, 1, 3, 29]
# [icode, inextposition, iw,ih] [140, 1, 2, 29]
# [icode, inextposition, iw,ih] [141, 2, 2, 30]
# [icode, inextposition, iw,ih] [142, 1, 1, 30]
# [icode, inextposition, iw,ih] [143, 3, 1, 29]
# [icode, inextposition, iw,ih] [144, 0, 2, 29]
# [icode, inextposition, iw,ih] [145, 2, 2, 30]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [146, 0, 4, 30]
# [icode, inextposition, iw,ih] [147, 2, 4, 31]
# [icode, inextposition, iw,ih] [148, 1, 3, 31]
# [icode, inextposition, iw,ih] [149, 3, 3, 30]
# [icode, inextposition, iw,ih] [150, 0, 4, 30]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [151, 3, 4, 28]
# [icode, inextposition, iw,ih] [152, 0, 5, 28]
# [icode, inextposition, iw,ih] [153, 2, 5, 29]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [154, 1, 3, 29]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [155, 1, 1, 29]
# [icode, inextposition, iw,ih] [156, 2, 1, 30]
# [icode, inextposition, iw,ih] [157, 0, 2, 30]
# [icode, inextposition, iw,ih] [158, 3, 2, 29]
# [icode, inextposition, iw,ih] [159, 0, 3, 29]
# [icode, inextposition, iw,ih] [160, 0, 4, 29]
# [icode, inextposition, iw,ih] [161, 0, 5, 29]
# [icode, inextposition, iw,ih] [162, 3, 5, 28]
# [icode, inextposition, iw,ih] [163, 1, 4, 28]
# [icode, inextposition, iw,ih] [164, 2, 4, 29]
# [icode, inextposition, iw,ih] [165, 1, 3, 29]
# diw 3    dih 3
# [icode, inextposition, iw,ih] [166, 3, 3, 26]
# [icode, inextposition, iw,ih] [167, 3, 3, 25]
# [icode, inextposition, iw,ih] [168, 1, 2, 25]
# [icode, inextposition, iw,ih] [169, 3, 2, 24]
# [icode, inextposition, iw,ih] [170, 1, 1, 24]
# [icode, inextposition, iw,ih] [171, 2, 1, 25]
# [icode, inextposition, iw,ih] [172, 2, 1, 26]
# [icode, inextposition, iw,ih] [173, 0, 2, 26]
# [icode, inextposition, iw,ih] [174, 0, 3, 26]
# [icode, inextposition, iw,ih] [175, 3, 3, 25]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [176, 0, 5, 25]
# [icode, inextposition, iw,ih] [177, 3, 5, 24]
# [icode, inextposition, iw,ih] [178, 1, 4, 24]
# [icode, inextposition, iw,ih] [179, 2, 4, 25]
# [icode, inextposition, iw,ih] [180, 0, 5, 25]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [181, 0, 7, 25]
# [icode, inextposition, iw,ih] [182, 0, 8, 25]
# [icode, inextposition, iw,ih] [183, 0, 9, 25]
# [icode, inextposition, iw,ih] [184, 2, 9, 26]
# [icode, inextposition, iw,ih] [185, 2, 9, 27]
# [icode, inextposition, iw,ih] [186, 0, 10, 27]
# [icode, inextposition, iw,ih] [187, 0, 11, 27]
# [icode, inextposition, iw,ih] [188, 2, 11, 28]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [189, 2, 11, 30]
# [icode, inextposition, iw,ih] [190, 0, 12, 30]
# [icode, inextposition, iw,ih] [191, 0, 13, 30]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [192, 2, 13, 32]
# [icode, inextposition, iw,ih] [193, 2, 13, 33]
# [icode, inextposition, iw,ih] [194, 1, 12, 33]
# [icode, inextposition, iw,ih] [195, 1, 11, 33]
# [icode, inextposition, iw,ih] [196, 3, 11, 32]
# [icode, inextposition, iw,ih] [197, 1, 10, 32]
# [icode, inextposition, iw,ih] [198, 2, 10, 33]
# [icode, inextposition, iw,ih] [199, 0, 11, 33]
# [icode, inextposition, iw,ih] [200, 0, 12, 33]
# [icode, inextposition, iw,ih] [201, 2, 12, 34]
# [icode, inextposition, iw,ih] [202, 1, 11, 34]
# [icode, inextposition, iw,ih] [203, 2, 11, 35]
# [icode, inextposition, iw,ih] [204, 0, 12, 35]
# [icode, inextposition, iw,ih] [205, 2, 12, 36]
# [icode, inextposition, iw,ih] [206, 0, 13, 36]
# [icode, inextposition, iw,ih] [207, 3, 13, 35]
# [icode, inextposition, iw,ih] [208, 1, 12, 35]
# [icode, inextposition, iw,ih] [209, 1, 11, 35]
# [icode, inextposition, iw,ih] [210, 2, 11, 36]
# [icode, inextposition, iw,ih] [211, 2, 11, 37]
# [icode, inextposition, iw,ih] [212, 2, 11, 38]
# [icode, inextposition, iw,ih] [213, 1, 10, 38]
# [icode, inextposition, iw,ih] [214, 1, 9, 38]
# [icode, inextposition, iw,ih] [215, 2, 9, 39]
# [icode, inextposition, iw,ih] [216, 2, 9, 40]
# [icode, inextposition, iw,ih] [217, 1, 8, 40]
# [icode, inextposition, iw,ih] [218, 1, 7, 40]
# [icode, inextposition, iw,ih] [219, 2, 7, 41]
# [icode, inextposition, iw,ih] [220, 2, 7, 42]
# [icode, inextposition, iw,ih] [221, 0, 8, 42]
# [icode, inextposition, iw,ih] [222, 2, 8, 43]
# [icode, inextposition, iw,ih] [223, 2, 8, 44]
# [icode, inextposition, iw,ih] [224, 0, 9, 44]
# [icode, inextposition, iw,ih] [225, 0, 10, 44]
# [icode, inextposition, iw,ih] [226, 3, 10, 43]
# [icode, inextposition, iw,ih] [227, 3, 10, 42]
# [icode, inextposition, iw,ih] [228, 0, 11, 42]
# [icode, inextposition, iw,ih] [229, 3, 11, 41]
# [icode, inextposition, iw,ih] [230, 0, 12, 41]
# [icode, inextposition, iw,ih] [231, 0, 13, 41]
# [icode, inextposition, iw,ih] [232, 3, 13, 40]
# [icode, inextposition, iw,ih] [233, 1, 12, 40]
# [icode, inextposition, iw,ih] [234, 3, 12, 39]
# [icode, inextposition, iw,ih] [235, 1, 11, 39]
# [icode, inextposition, iw,ih] [236, 3, 11, 38]
# [icode, inextposition, iw,ih] [237, 1, 10, 38]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [238, 3, 10, 36]
# [icode, inextposition, iw,ih] [239, 1, 9, 36]
# [icode, inextposition, iw,ih] [240, 2, 9, 37]
# [icode, inextposition, iw,ih] [241, 1, 8, 37]
# [icode, inextposition, iw,ih] [242, 2, 8, 38]
# [icode, inextposition, iw,ih] [243, 2, 8, 39]
# [icode, inextposition, iw,ih] [244, 2, 8, 40]
# [icode, inextposition, iw,ih] [245, 0, 9, 40]
# [icode, inextposition, iw,ih] [246, 3, 9, 39]
# [icode, inextposition, iw,ih] [247, 3, 9, 38]
# [icode, inextposition, iw,ih] [248, 0, 10, 38]
# [icode, inextposition, iw,ih] [249, 0, 11, 38]
# [icode, inextposition, iw,ih] [250, 2, 11, 39]
# [icode, inextposition, iw,ih] [251, 0, 12, 39]
# [icode, inextposition, iw,ih] [252, 0, 13, 39]
# [icode, inextposition, iw,ih] [253, 0, 14, 39]
# [icode, inextposition, iw,ih] [254, 0, 15, 39]
# [icode, inextposition, iw,ih] [255, 0, 16, 39]
# [icode, inextposition, iw,ih] [256, 3, 16, 38]
# [icode, inextposition, iw,ih] [257, 1, 15, 38]
# [icode, inextposition, iw,ih] [258, 2, 15, 39]
# [icode, inextposition, iw,ih] [259, 1, 14, 39]
# [icode, inextposition, iw,ih] [260, 1, 13, 39]
# [icode, inextposition, iw,ih] [261, 1, 12, 39]
# [icode, inextposition, iw,ih] [262, 1, 11, 39]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [263, 3, 11, 37]
# [icode, inextposition, iw,ih] [264, 3, 11, 36]
# [icode, inextposition, iw,ih] [265, 0, 12, 36]
# [icode, inextposition, iw,ih] [266, 0, 13, 36]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [267, 3, 13, 34]
# [icode, inextposition, iw,ih] [268, 0, 14, 34]
# [icode, inextposition, iw,ih] [269, 0, 15, 34]
# [icode, inextposition, iw,ih] [270, 3, 15, 33]
# [icode, inextposition, iw,ih] [271, 1, 14, 33]
# [icode, inextposition, iw,ih] [272, 2, 14, 34]
# [icode, inextposition, iw,ih] [273, 0, 15, 34]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [274, 0, 17, 34]
# [icode, inextposition, iw,ih] [275, 0, 18, 34]
# [icode, inextposition, iw,ih] [276, 2, 18, 35]
# [icode, inextposition, iw,ih] [277, 2, 18, 36]
# [icode, inextposition, iw,ih] [278, 2, 18, 37]
# [icode, inextposition, iw,ih] [279, 0, 19, 37]
# [icode, inextposition, iw,ih] [280, 3, 19, 36]
# [icode, inextposition, iw,ih] [281, 0, 20, 36]
# [icode, inextposition, iw,ih] [282, 0, 21, 36]
# [icode, inextposition, iw,ih] [283, 0, 22, 36]
# [icode, inextposition, iw,ih] [284, 3, 22, 35]
# [icode, inextposition, iw,ih] [285, 3, 22, 34]
# [icode, inextposition, iw,ih] [286, 1, 21, 34]
# [icode, inextposition, iw,ih] [287, 2, 21, 35]
# [icode, inextposition, iw,ih] [288, 0, 22, 35]
# [icode, inextposition, iw,ih] [289, 2, 22, 36]
# [icode, inextposition, iw,ih] [290, 0, 23, 36]
# [icode, inextposition, iw,ih] [291, 3, 23, 35]
# [icode, inextposition, iw,ih] [292, 0, 24, 35]
# [icode, inextposition, iw,ih] [293, 0, 25, 35]
# [icode, inextposition, iw,ih] [294, 2, 25, 36]
# [icode, inextposition, iw,ih] [295, 1, 24, 36]
# [icode, inextposition, iw,ih] [296, 3, 24, 35]
# [icode, inextposition, iw,ih] [297, 0, 25, 35]
# diw 2    dih 2
# [icode, inextposition, iw,ih] [298, 0, 27, 35]
# [icode, inextposition, iw,ih] [299, 0, 28, 35]
# [icode, inextposition, iw,ih] [300, 0, 29, 35]

# %%
ratio = int(400/min([divh,divw]))
decolor_img = np.zeros((ratio*divh, ratio*divw, 3), np.uint8)
dr = int(ratio/3)
orbitimgs = []
for i in range(len(iwhs)):
    iw = np.array(iwhs)[i,0]
    ih = np.array(iwhs)[i,1]
    if(i>0):
        iwold = np.array(iwhs)[i-1,0]
        ihold = np.array(iwhs)[i-1,1]
        cv2.rectangle(decolor_img, (ratio*iwold, ratio*ihold), (ratio*(iwold+1)-1, ratio*(ihold+1)-1), codesRGBF[i-1], -1, 0)
    cv2.rectangle(decolor_img, (ratio*iw, ratio*ih), (ratio*(iw+1)-1, ratio*(ih+1)-1), codesRGBF[i], -1, 0)
    cv2.rectangle(decolor_img, (ratio*iw+dr, ratio*ih+dr), (ratio*(iw+1)-1-dr, ratio*(ih+1)-1-dr), np.array([255.,255.,255.]), -1, 0)
    cv2.imwrite("orbit_dc_melody/decolor-orbit"+str(i)+".jpg", cv2.cvtColor(decolor_img,cv2.COLOR_RGB2BGR) )
    orbitimgs.append( cv2.cvtColor(decolor_img,cv2.COLOR_RGB2BGR) )
plt.imshow(decolor_img)

# %%
# print(codesHSVF)
Hs = codesHSVF[:,0]
Ss = codesHSVF[:,1]
Vs = codesHSVF[:,2]

fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)

ax1.plot(Hs)
ax2.plot(Ss)
ax3.plot(Vs)

# %% [markdown]
# ### musicize

# %%
initial_octave = 3 #3:[A4,...], 4:[A5,...] 
initial_key = 12 # A:0, C:3
plus_octave = 2

T0old = 0
Tmin = 0
T0ratio = 1
Tratio = 1
bpm = 120
time1count = 60/bpm
time1loop = 8*time1count
time1loophalf = time1loop/2
dT0 = time1count/2
dT = time1count/2
#dT = Tbase/2
##dT = 0.2
#Tratio = 2.4

sr = 44100 # sampling rate ex.44100Hz

# t1: time of peak
# a1: trancation exponent(a1=1: NoEffect, 1<<a1: too tracate)
# a2: trancation exponent(0<a2, 0<a2<<1: too tracate, 1<<a2: NoEffect
# a1=-1&a2=1: convex trancation shape

start_time = time.time()
wave_temp = []
#lens = []
freqs = []
Ts = []
T0s = []
Hmin = min(Hs)
Hmax = max(Hs)
Smin = min(Ss)
Smax = max(Ss)
Vmin = min(Vs)
Vmax = max(Vs)
for i in range(len(Hs)):
    freq = hue2key(initial_octave, plus_octave, initial_key, [Hs[i],Hmin,Hmax])
    freqs.append(freq)
    Stld = (Ss[i]-Smin)/(Smax-Smin)
    Vtld = (Vs[i]-Vmin)/(Vmax-Vmin)
    if(i==0):
        T0 = 0
    elif(i>0):
        T0 = T0old + dT0*int(T0ratio*(1-Stld)+1)
    T0s.append(T0)
    T0old = T0

    if( i<(len(Hs)-1) ):
        T = Tmin + dT*int(Tratio*(1-Stld)+1)
    elif( i==(len(Hs)-1) ):
        for ii in range(2):
            if( ii*time1loophalf<T0<(ii+1)*time1loophalf ):
                dTlastratio=int(((ii+1)*time1loophalf-T0)/dT)
                print("hello", ii, dTlastratio)
                T = Tmin + dT*(int(dTlastratio*(1-Stld)+1))
    Ts.append(T)
    
    aparam = [0.02*T*Vtld, 1, 0.1*Vtld] #t1,a1,a2
#    aparam = [0.02*T, 1, 0.1] #t1,a1,a2
#    wave_temp0 = makeampFnwave(1, freq, T, dT, sr, aparam)
    wave_temp0 = makeampFnwave(1, freq, T, sr, aparam)
    
    bfr0 = int(T0*sr)
#    bfr0 = int(T0*100000)
    wave_temp0 = np.lib.pad(wave_temp0,(bfr0, 0),"constant",constant_values = 0)
    if(i==0):
        wave_temp1 = wave_temp0
    elif(i>0):
        wave_temp1 = merge1d(wave_temp0, wave_temp1)
        
wave0 = wave_temp1
wave_melody_base = wave0
end_time = time.time()
elapsed_time = end_time - start_time
print(elapsed_time, "sec   ", elapsed_time/60, "min   ", elapsed_time/3600, "hour")
# Out:
# 40.92551898956299 sec    0.6820919831593831 min    0.011368199719323051 hour

# %%
fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(141)
ax2 = fig.add_subplot(142)
ax3 = fig.add_subplot(143)
ax4 = fig.add_subplot(144)

#C3:130.81, B3:246.94, C4:261.63, B4:493.88, C5:523,25
ax1.plot(wave0)
ax2.plot(T0s)
ax3.plot(Ts)
ax4.plot(freqs)

# %%
wave0max = max(abs(wave0))
print(wave0max)
wave0 = wave0/wave0max
wavwrite(wave0,"music_w"+str(divw)+"h"+str(divh)+".wav")
# Out:
# 1.28145126989

# %%
wave_melody = wave0

# %% [markdown]
# ## loop part --------------------------------------------------

# %%
divw = 2
divh = 2
heights, widths, dividedimgs = divideimage(img, divw, divh)
#print(dividedimgs.shape)
#dividedimgs

# %%
decolorRGBs = []
decolorHSVs = []
for iw in range(divw):
    tempRGB = []
    tempHSV = []
    for ih in range(divh):
#        meanRGB = mean_image(dividedimgs[ih,iw])
#        print(dividedimgs[ih][iw])
        meanRGB = mean_image(dividedimgs[ih][iw])
#        print(meanRGB)
        tempRGB.append( meanRGB )
        tempHSV.append( rgb2hsv(meanRGB[0],meanRGB[1],meanRGB[2]) )
    decolorRGBs.append(tempRGB)
    decolorHSVs.append(tempHSV)
decolorRGBs = np.array(decolorRGBs)
decolorHSVs = np.array(decolorHSVs)

print(decolorRGBs.shape)
# Out:
# (2, 2, 3)

# %%
codesRGBF = []
codesHSVF = []
codes = []
icode = 0
iw = int(divw/2)
ih = int(divh/2)
codesRGBF.append( decolorRGBs[iw,ih] )
codesRGBF = np.array(codesRGBF)
#print(codesRGBF)

codesHSVF.append( decolorHSVs[iw,ih] )
codesHSVF = np.array(codesHSVF)
#print(codesHSVF)

#icode0 = 0
icodemax = 300
diw = 1
dih = 1
iwhssetall = []
icheckth = 1
for iih in range(divh):
    for iiw in range(divw):
        iwhssetall.append(str(iiw)+","+str(iih))
        
iwhsset = set([])
iwhs = []
ilogs = []
iwhs.append([iw,ih])
ilogs.append([0,9,iw,ih])
print("[icode, inextposition, iw,ih]", ilogs[0])
inextpositions = []
icheck = 0
#for ii in range(icodemax):
while (len(iwhsset) != len(iwhssetall)) and (icode < icodemax) :
    icode = icode + 1
                
    nextsRGBF = []
    nextsHSVF = []
    inextpositionBoundaries =[]
    iBoundaries = [0,0,0,0]
    if(iw+diw <= divw-1):
        nextsRGBF.append( decolorRGBs[iw+diw,ih] )
        nextsHSVF.append( decolorHSVs[iw+diw,ih] )
    else:
        if(iw < divw-1):
            nextsRGBF.append( decolorRGBs[divw-1,ih] )
            nextsHSVF.append( decolorHSVs[divw-1,ih] )
            iBoundaries[0] = 1
        else:
            nextsRGBF.append( np.array([random.random(),random.random(),random.random()]) )
            nextsHSVF.append( [random.random(),random.random(),random.random()] )
            inextpositionBoundaries.append(0)

    if(iw-diw >= 0):
        nextsRGBF.append( decolorRGBs[iw-diw,ih] )
        nextsHSVF.append( decolorHSVs[iw-diw,ih] )
    else:
        if(iw > 0):
            nextsRGBF.append( decolorRGBs[0,ih] )
            nextsHSVF.append( decolorHSVs[0,ih] )
            iBoundaries[1] = 1
        else:
            nextsRGBF.append( np.array([random.random(),random.random(),random.random()]) )
            inextpositionBoundaries.append(1)
            nextsHSVF.append( [random.random(),random.random(),random.random()] )

    if(ih+dih <= divh-1):
        nextsRGBF.append( decolorRGBs[iw,ih+dih] )
        nextsHSVF.append( decolorHSVs[iw,ih+dih] )
    else:
        if(ih < divh-1):
            nextsRGBF.append( decolorRGBs[iw,divh-1] )
            nextsHSVF.append( decolorHSVs[iw,divh-1] )
            iBoundaries[2] = 1
        else:
            nextsRGBF.append( np.array([random.random(),random.random(),random.random()]) )
            inextpositionBoundaries.append(2)
            nextsHSVF.append( [random.random(),random.random(),random.random()] )

    if(ih-dih >= 0):
        nextsRGBF.append( decolorRGBs[iw,ih-dih] )
        nextsHSVF.append( decolorHSVs[iw,ih-dih] )
    else:
        if(ih > 0):
            nextsRGBF.append( decolorRGBs[iw,0] )
            nextsHSVF.append( decolorHSVs[iw,0] )
            iBoundaries[3] = 1
        else:
            nextsRGBF.append( np.array([random.random(),random.random(),random.random()]) )
            inextpositionBoundaries.append(3)
            nextsHSVF.append( [random.random(),random.random(),random.random()] )
            #print("hello3c")

    nextsHSVF = np.array(nextsHSVF)
    nextsRGBF = np.array(nextsRGBF)

    nextsHF = nextsHSVF[:,0]
    dHues = abs( nextsHF - codesHSVF[icode-1,0] )
    
    dHuesSort = np.sort(dHues)
    dHuesSort

    dHuesindex = []
    for i in range(len(dHues)):
        dHuesindex.append( dHues.tolist().index(dHuesSort[i]) )

    dHuesindexbad = set([])
    if( icode > 1 ):
        if( inextpositionold != 9 ):
            dHuesindexbad.add( dHuesindex.index(inextpositionold) )
    if(len(inextpositionBoundaries) > 0):
        for i in range(len(inextpositionBoundaries)):
            if( icode > 1 ):
                if( inextpositionold != 9 ):
                    if( dHuesindex.index(inextpositionold) != dHuesindex.index(inextpositionBoundaries[i]) ):
                        dHuesindexbad.add( dHuesindex.index(inextpositionBoundaries[i]) )
    dHuesindexbad = list(dHuesindexbad)

    dHuesindexbad = sorted(dHuesindexbad, reverse=True)

    if( len(dHuesindexbad) > 0 ):
        for i in range( len(dHuesindexbad) ):
            dHuesindex.pop( dHuesindexbad[i] )

    inextposition = dHuesindex[0]   #close color
#    inextposition = dHuesindex[ len(dHuesindex)-1 ]   #different color
#    inextposition = dHuesindex[ random.randint(0,len(dHuesindex)-1) ]
    inextpositions.append(inextposition)

    codesRGBF = np.concatenate(np.array([codesRGBF, [nextsRGBF[inextposition]] ]))
    codesHSVF = np.concatenate(np.array([codesHSVF, [nextsHSVF[inextposition]] ]))

    if(inextposition == 0):
        if(iBoundaries[inextposition] == 1):
            iw = divw - 1
        else:
            iw = iw + diw
        inextpositionold = 1
            
    if(inextposition == 1):
        if(iBoundaries[inextposition] == 1):
            iw = 0
        else:
            iw = iw - diw
        inextpositionold = 0
    if(inextposition == 2):
        if(iBoundaries[inextposition] == 1):
            ih = divh - 1
        else:
            ih = ih + dih
        inextpositionold = 3
    if(inextposition == 3):
        if(iBoundaries[inextposition] == 1):
            ih = 0
        else:
            ih = ih - dih
        inextpositionold = 2
    if(np.mod(icode,1)==0):
#    if(icode>10):
        print("[icode, inextposition, iw,ih]", [icode, inextposition, iw,ih])
    iwhsset.add(str(iw)+","+str(ih))
    
    diw = 1
    dih = 1
    ilogscount = ilogs.count([inextposition,iw,ih])
    if( ilogscount > 0 ):
        dih = ilogscount + 1
        diw = ilogscount + 1
        deltaiwsort = sorted([abs(divw-iw)-1,iw])
        deltaihsort = sorted([abs(divh-ih)-1,ih])
        if( deltaiwsort[1] < diw ):
            diw = deltaiwsort[0]
            if( deltaiwsort[0] == 0 ):
                diw = deltaiwsort[0] + 1
        if( deltaihsort[1] < dih ):
            dih = deltaihsort[0]
            if( deltaihsort[0] == 0 ):
                dih = deltaihsort[0] + 1
        print("diw", diw, "   dih", dih)
        
        if( icheck < icheckth ):
            if( deltaiwsort[0] == 0 ):
                if( deltaihsort[0] == 0 ):
                    icheck += 1
        if( icheck == icheckth ):
            if( deltaiwsort[0] == 0 ):
                if( deltaihsort[0] == 0 ):
                    if(set(iwhssetall) != iwhsset):
                        iwhssetrem = set(iwhssetall).difference(iwhsset)
                        iwhsrem=",".join(iwhssetrem)
                        iwhsrem=iwhsrem.split(",")
                        iw = int(iwhsrem[0])
                        ih = int(iwhsrem[1])

                    if(set(iwhssetall) == iwhsset):
                        iw = np.array(iwhs)[0,0]
                        ih = np.array(iwhs)[0,1]
            
                    inextposition = 9
                    print("[icode, inextposition, iw,ih]", [icode, inextposition, iw,ih])
                    iwhsset.add(str(iw)+","+str(ih))
                    
                    icheck = 0

                    codesRGBF[icode] = decolorRGBs[iw,ih]
                    codesHSVF[icode] = decolorHSVs[iw,ih]
                    inextposition = 9

    iwhs.append([iw,ih])
    ilogs.append([inextposition,iw,ih])
# Out:
# [icode, inextposition, iw,ih] [0, 9, 1, 1]
# [icode, inextposition, iw,ih] [1, 1, 0, 1]
# [icode, inextposition, iw,ih] [2, 3, 0, 0]
# [icode, inextposition, iw,ih] [3, 0, 1, 0]
# [icode, inextposition, iw,ih] [4, 2, 1, 1]

# %%
ratio = int(400/min([divh,divw]))
decolor_img = np.zeros((ratio*divh, ratio*divw, 3), np.uint8)
dr = int(ratio/3)
orbitimgs = []
for i in range(len(iwhs)):
    iw = np.array(iwhs)[i,0]
    ih = np.array(iwhs)[i,1]
    if(i>0):
        iwold = np.array(iwhs)[i-1,0]
        ihold = np.array(iwhs)[i-1,1]
        cv2.rectangle(decolor_img, (ratio*iwold, ratio*ihold), (ratio*(iwold+1)-1, ratio*(ihold+1)-1), codesRGBF[i-1], -1, 0)
    cv2.rectangle(decolor_img, (ratio*iw, ratio*ih), (ratio*(iw+1)-1, ratio*(ih+1)-1), codesRGBF[i], -1, 0)
    cv2.rectangle(decolor_img, (ratio*iw+dr, ratio*ih+dr), (ratio*(iw+1)-1-dr, ratio*(ih+1)-1-dr), np.array([255.,255.,255.]), -1, 0)
    cv2.imwrite("orbit_dc_loop/decolor-orbit"+str(i)+".jpg", cv2.cvtColor(decolor_img,cv2.COLOR_RGB2BGR) )
    orbitimgs.append( cv2.cvtColor(decolor_img,cv2.COLOR_RGB2BGR) )
plt.imshow(decolor_img)

# %%
# print(codesHSVF)
Hs = codesHSVF[:,0]
Ss = codesHSVF[:,1]
Vs = codesHSVF[:,2]

fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)

ax1.plot(Hs)
ax2.plot(Ss)
ax3.plot(Vs)

# %% [markdown]
# ### musicize

# %%
initial_octave = 3 #3:[A4,...], 4:[A5,...] 
initial_key = 12 # A:0, C:3
plus_octave = 1

T0old = 0
Tmin = 0
T0ratio = 1
Tratio = 1
bpm = 120
time1count = 60/bpm
time1loop = 8*time1count
time1loophalf = time1loop/2
dT0 = time1count/2
dT = time1count/2
#dT = Tbase/2
##dT = 0.2
#Tratio = 2.4

sr = 44100 # sampling rate ex.44100Hz

# t1: time of peak
# a1: trancation exponent(a1=1: NoEffect, 1<<a1: too tracate)
# a2: trancation exponent(0<a2, 0<a2<<1: too tracate, 1<<a2: NoEffect
# a1=-1&a2=1: convex trancation shape

start_time = time.time()
wave_temp = []
#lens = []
freqs = []
Ts = []
T0s = []
Hmin = min(Hs)
Hmax = max(Hs)
Smin = min(Ss)
Smax = max(Ss)
Vmin = min(Vs)
Vmax = max(Vs)
for i in range(len(Hs)):
    freq = hue2key(initial_octave, plus_octave, initial_key, [Hs[i],Hmin,Hmax])
    freqs.append(freq)
    Stld = (Ss[i]-Smin)/(Smax-Smin)
    Vtld = (Vs[i]-Vmin)/(Vmax-Vmin)
    if(i==0):
        T0 = 0
    elif(i>0):
        T0 = T0old + dT0*int(T0ratio*(1-Stld)+1)
    T0s.append(T0)
    T0old = T0

    if( i<(len(Hs)-1) ):
        T = Tmin + dT*int(Tratio*(1-Stld)+1)
    elif( i==(len(Hs)-1) ):
        for ii in range(2):
            if( ii*time1loophalf<T0<(ii+1)*time1loophalf ):
                dTlastratio=int(((ii+1)*time1loophalf-T0)/dT)
                print("hello", ii, dTlastratio)
                T = Tmin + dT*(int(dTlastratio*(1-Stld)+1))
    Ts.append(T)
    
    aparam = [0.02*T*Vtld, 1, 0.1*Vtld] #t1,a1,a2
#    aparam = [0.02*T, 1, 0.1] #t1,a1,a2
#    wave_temp0 = makeampFnwave(1, freq, T, dT, sr, aparam)
    wave_temp0 = makeampFnwave(1, freq, T, sr, aparam)
    
    bfr0 = int(T0*sr)
#    bfr0 = int(T0*100000)
    wave_temp0 = np.lib.pad(wave_temp0,(bfr0, 0),"constant",constant_values = 0)
    if(i==0):
        wave_temp1 = wave_temp0
    elif(i>0):
        wave_temp1 = merge1d(wave_temp0, wave_temp1)
        
wave0 = wave_temp1
wave_loop_base = wave0
end_time = time.time()
elapsed_time = end_time - start_time
print(elapsed_time, "sec   ", elapsed_time/60, "min   ", elapsed_time/3600, "hour")
# Out:
# hello 0 3
# 0.6904199123382568 sec    0.011506998538970947 min    0.00019178330898284913 hour

# %%
fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(141)
ax2 = fig.add_subplot(142)
ax3 = fig.add_subplot(143)
ax4 = fig.add_subplot(144)

#C3:130.81, B3:246.94, C4:261.63, B4:493.88, C5:523,25
ax1.plot(wave0)
ax2.plot(T0s)
ax3.plot(Ts)
ax4.plot(freqs)

# %%
wave0max = max(abs(wave0))
print(wave0max)
wave0 = wave0/wave0max
wave0 = list(wave0)
wave0 = wave0 + wave0 + wave0 + wave0 + wave0 + wave0 + wave0 + wave0 + wave0 + wave0
wave0 = wave0 + wave0 + wave0 + wave0 + wave0
wavwrite(wave0,"music_w"+str(divw)+"h"+str(divh)+".wav")
# Out:
# 1.31299324869

# %%
wave_loop = wave0

# %% [markdown]
# ## Mix melody and loop ---------------------------------------

# %%
wave0 = merge1d(wave_melody, wave_loop)

# %%
wave0max = max(abs(wave0))
print(wave0max)
wave0 = wave0/wave0max
wavwrite(wave0,"music_mix.wav")
# Out:
# 1.80925873697

# %%
end_whole_time = time.time()
elapsed_whole_time = end_whole_time - start_whole_time
print(elapsed_whole_time, "sec   ", elapsed_whole_time/60, "min   ", elapsed_whole_time/3600, "hour")
# Out:
# 88.78488206863403 sec    1.4797480344772338 min    0.02466246724128723 hour
